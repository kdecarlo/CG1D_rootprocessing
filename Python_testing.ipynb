# %%
# %matplotlib inline                
#plot inside browser
import matplotlib.pyplot as plt    #brings in library of matplotlib
import numpy as np

# %%
f = open('/Users/kdecarlo/Python_scripts/RD_WC.txt', 'r')  #rhizosphere vs water content
data_x = np.array([])
data_y = np.array([])
for line in f:
    newline = line.strip()
    splitline = newline.split('  ')
    num_L = np.float(splitline[0])
    num_R = np.float(splitline[1])
    data_x = np.append(data_x, num_L)
    data_y = np.append(data_y, num_R)
f.close()

data_xy = np.transpose([data_x, data_y])

# %%
x = data_xy[:, 0]
y = data_xy[:, 1]

# %%
f = open('/Users/kdecarlo/Python_scripts/RD_WC.txt', 'r')  #rhizosphere vs water content
data_xy = []
for line in f:
    newline = line.strip()
    splitline = newline.split('  ')
    num_L = np.float(splitline[0])
    num_R = np.float(splitline[1])
    data_xy.append([num_L, num_R])
f.close()

# %%
np.shape(data_xy)
# Out:
# (224, 2)

# %%
data_xy
# Out:
# array([], dtype=float64)

# %%
data_x = []
data_y = []
for line in data_xy:
    E_1 = line[0]
    E_2 = line[1]
    data_x.append(E_1)
    data_y.append(E_2)

# %%
np.shape(data_x)
# Out:
# (224,)

# %%
type(D_1)
# Out:
# list

# %%
D_1 = data_xy[0]
D_1[0]
type(D_1[0])
# Out:
# float

# %%
type(data_xy)
# Out:
# list

# %%
np.shape(data_xy)

# %%
from PIL import Image
image = Image.open('/Users/kdecarlo/Python_scripts/collaget0-1.tif')

# %%
type(image)
# Out:
# PIL.TiffImagePlugin.TiffImageFile

# %%
import numpy as np

# %%
data = np.array(image)

# %%
data[200, 200]
# Out:
# 0.71033132

# %%
datasubset = data[2000:3000, 2000:3000]

# %%
plt.imshow(datasubset)

# %%
fig = plt.scatter(x, y, 20, [0, 0, 0])
plt.xlim([0, 0.23])
plt.ylim([np.min(data_y), np.max(data_y)])
# Out:
# (-0.001745, 0.00013799999999999999)

# %%
fig.savefig('/Users/kdecarlo/Python_scripts/fig.tiff', format = 'tiff')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-c7cfaec5b74f> in <module>()
# ----> 1 fig.savefig('/Users/kdecarlo/Python_scripts/fig.tiff', format = 'tiff')
#
# AttributeError: 'PathCollection' object has no attribute 'savefig'

# %%
data_xy[1, 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-eccd58b13001> in <module>()
# ----> 1 data_xy[1, 0]
#
# TypeError: list indices must be integers or slices, not tuple
